# %%
url1 = "https://en.wikipedia.org/wiki/Category:African-American_actresses"

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd

# %%
response1 = requests.get(url1)

# %%
response2
# Out:
# <Response [200]>

# %%
soup1=BeautifulSoup(response1.content, "html.parser")

# %%
names_html1=soup1.select("#mw-pages li a")

# %%
names=[]
for i in range(len(names_html1)):
    names.append(names_html1[i].get_text())
names
# Out:
# ['List of former African-American child actors',
#  'Mariann Aalda',
#  'Aaliyah',
#  'Diahnne Abbott',
#  'Loretta Abbott',
#  'Donzaleigh Abernathy',
#  'Acquanetta',
#  'Janeshia Adams-Ginyard',
#  'Chanté Adams',
#  'Osceola Macarthy Adams',
#  'Yolanda Adams',
#  'Cynthia Addai-Robinson',
#  'Erika Alexander',
#  'Khandi Alexander',
#  'Ajiona Alexus',
#  'Tatyana Ali',
#  'Mary Alice',
#  'Billie Allen',
#  'Debbie Allen',
#  'Jonelle Allen',
#  'Lexi Allen',
#  'Sasha Allen',
#  'Amerie',
#  'Ismay Andrews',
#  'Angel Theory',
#  'Maya Angelou',
#  'Cecelia Antoinette',
#  'Leila Arcieri',
#  'Coretti Arle-Titz',
#  'Tichina Arnold',
#  'Lisa Arrindell Anderson',
#  'Ashanti (singer)',
#  'Karan Ashley',
#  'Essence Atkins',
#  'Beverly Hope Atkinson',
#  'Ruth Attaway',
#  'K. D. Aubert',
#  'Ashley August',
#  'Margaret Avery',
#  'Shondrella Avery',
#  'Ethel Ayler',
#  'Rochelle Aytes',
#  "De'Adre Aziza",
#  'Vanessa Baden',
#  'Erykah Badu',
#  'Cynthia Bailey',
# ...

# %%
df=pd.DataFrame(names, columns=['name'])
df['ethn']='african-american'
df
df.to_excel('AF-AM-Female.xlsx')
