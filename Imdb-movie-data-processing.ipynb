# %%
# IMDB full movie data scraping

# %%
import requests                  
from bs4 import BeautifulSoup   
import pandas as pd             
import re                      
import json                    
from tqdm import tqdm           
from datetime import datetime

# %%
#add scraped movie URL list ## didnt have time for pickles

# %%
title_links=[
'https://www.imdb.com/title/tt6723592/',
'https://www.imdb.com/title/tt9770150/',
'https://www.imdb.com/title/tt8332922/',
'https://www.imdb.com/title/tt9620292/',
'https://www.imdb.com/title/tt7737786/',
'https://www.imdb.com/title/tt1270797/',
'https://www.imdb.com/title/tt2850272/',
'https://www.imdb.com/title/tt2222042/',
'https://www.imdb.com/title/tt5363618/',
'https://www.imdb.com/title/tt4154796/',
'https://www.imdb.com/title/tt6644200/',
'https://www.imdb.com/title/tt10633456/',
'https://www.imdb.com/title/tt7131622/',
'https://www.imdb.com/title/tt8946378/',
'https://www.imdb.com/title/tt7126948/',
'https://www.imdb.com/title/tt8772262/',
'https://www.imdb.com/title/tt2283336/',
'https://www.imdb.com/title/tt2948372/',
'https://www.imdb.com/title/tt8368512/',
'https://www.imdb.com/title/tt5144174/',
'https://www.imdb.com/title/tt8367814/',
'https://www.imdb.com/title/tt9224288/',
'https://www.imdb.com/title/tt9893250/',
'https://www.imdb.com/title/tt2066051/',
'https://www.imdb.com/title/tt0816692/',
'https://www.imdb.com/title/tt3890160/',
'https://www.imdb.com/title/tt7286456/',
'https://www.imdb.com/title/tt6060444/',
'https://www.imdb.com/title/tt0993846/',
'https://www.imdb.com/title/tt1838556/',
'https://www.imdb.com/title/tt1825683/',
'https://www.imdb.com/title/tt9484998/',
'https://www.imdb.com/title/tt1070874/',
'https://www.imdb.com/title/tt6269368/',
'https://www.imdb.com/title/tt7395114/',
'https://www.imdb.com/title/tt5463162/',
'https://www.imdb.com/title/tt1853728/',
'https://www.imdb.com/title/tt2101341/',
'https://www.imdb.com/title/tt1392170/',
'https://www.imdb.com/title/tt3501632/',
'https://www.imdb.com/title/tt4154664/',
'https://www.imdb.com/title/tt2015381/',
'https://www.imdb.com/title/tt4154756/',
'https://www.imdb.com/title/tt9689696/',
'https://www.imdb.com/title/tt8633478/',
'https://www.imdb.com/title/tt7826276/',
'https://www.imdb.com/title/tt3503406/',
'https://www.imdb.com/title/tt1856101/',
'https://www.imdb.com/title/tt9691136/',
'https://www.imdb.com/title/tt10059518/',
'https://www.imdb.com/title/tt4682266/',
'https://www.imdb.com/title/tt7752126/',
'https://www.imdb.com/title/tt8579674/',
'https://www.imdb.com/title/tt3896198/',
'https://www.imdb.com/title/tt2379713/',
'https://www.imdb.com/title/tt1431045/',
'https://www.imdb.com/title/tt2119532/',
'https://www.imdb.com/title/tt6806448/',
'https://www.imdb.com/title/tt7784604/',
'https://www.imdb.com/title/tt1392190/',
'https://www.imdb.com/title/tt1386697/',
'https://www.imdb.com/title/tt1972591/',
'https://www.imdb.com/title/tt4566758/',
'https://www.imdb.com/title/tt6878306/',
'https://www.imdb.com/title/tt1240982/',
'https://www.imdb.com/title/tt2395427/',
'https://www.imdb.com/title/tt7397098/',
'https://www.imdb.com/title/tt5027774/',
'https://www.imdb.com/title/tt2267998/',
'https://www.imdb.com/title/tt2250912/',
'https://www.imdb.com/title/tt10702148/',
'https://www.imdb.com/title/tt0458339/',
'https://www.imdb.com/title/tt1485796/',
'https://www.imdb.com/title/tt6475714/',
'https://www.imdb.com/title/tt0974015/',
'https://www.imdb.com/title/tt1392214/',
'https://www.imdb.com/title/tt1345836/',
'https://www.imdb.com/title/tt2911666/',
'https://www.imdb.com/title/tt2543164/',
'https://www.imdb.com/title/tt4912910/',
'https://www.imdb.com/title/tt2527338/',
'https://www.imdb.com/title/tt1396484/',
'https://www.imdb.com/title/tt8503618/',
'https://www.imdb.com/title/tt10618286/',
'https://www.imdb.com/title/tt2582802/',
'https://www.imdb.com/title/tt1661199/',
'https://www.imdb.com/title/tt4126476/',
'https://www.imdb.com/title/tt7713068/',
'https://www.imdb.com/title/tt1727824/',
'https://www.imdb.com/title/tt1677720/',
'https://www.imdb.com/title/tt2584384/',
'https://www.imdb.com/title/tt1843866/',
'https://www.imdb.com/title/tt0848228/',
'https://www.imdb.com/title/tt0800369/',
'https://www.imdb.com/title/tt0448115/',
'https://www.imdb.com/title/tt1074638/',
'https://www.imdb.com/title/tt1950186/',
'https://www.imdb.com/title/tt8639136/',
'https://www.imdb.com/title/tt1517451/',
'https://www.imdb.com/title/tt2322441/',
'https://www.imdb.com/title/tt4633694/',
'https://www.imdb.com/title/tt9686708/',
'https://www.imdb.com/title/tt7349950/',
'https://www.imdb.com/title/tt10362466/',
'https://www.imdb.com/title/tt1302006/',
'https://www.imdb.com/title/tt7984734/',
'https://www.imdb.com/title/tt1979320/',
'https://www.imdb.com/title/tt5688068/',
'https://www.imdb.com/title/tt1259528/',
'https://www.imdb.com/title/tt9016974/',
'https://www.imdb.com/title/tt3281548/',
'https://www.imdb.com/title/tt1959563/',
'https://www.imdb.com/title/tt5013056/',
'https://www.imdb.com/title/tt6320628/',
'https://www.imdb.com/title/tt2278388/',
'https://www.imdb.com/title/tt6966692/',
'https://www.imdb.com/title/tt6823368/',
'https://www.imdb.com/title/tt3498820/',
'https://www.imdb.com/title/tt1833116/',
'https://www.imdb.com/title/tt0451279/',
'https://www.imdb.com/title/tt4824302/',
'https://www.imdb.com/title/tt4779682/',
'https://www.imdb.com/title/tt5726616/',
'https://www.imdb.com/title/tt5052448/',
'https://www.imdb.com/title/tt1457767/',
'https://www.imdb.com/title/tt0903624/',
'https://www.imdb.com/title/tt8580274/',
'https://www.imdb.com/title/tt2543472/',
'https://www.imdb.com/title/tt3748528/',
'https://www.imdb.com/title/tt3521164/',
'https://www.imdb.com/title/tt1477834/',
'https://www.imdb.com/title/tt1211837/',
'https://www.imdb.com/title/tt1570728/',
'https://www.imdb.com/title/tt4972582/',
'https://www.imdb.com/title/tt2283362/',
'https://www.imdb.com/title/tt2674426/',
'https://www.imdb.com/title/tt1478338/',
'https://www.imdb.com/title/tt3553976/',
'https://www.imdb.com/title/tt2713180/',
'https://www.imdb.com/title/tt6565702/',
'https://www.imdb.com/title/tt1981677/',
'https://www.imdb.com/title/tt3104988/',
'https://www.imdb.com/title/tt6189022/',
'https://www.imdb.com/title/tt4550098/',
'https://www.imdb.com/title/tt1201607/',
'https://www.imdb.com/title/tt2139881/',
'https://www.imdb.com/title/tt1285009/',
'https://www.imdb.com/title/tt3348730/',
'https://www.imdb.com/title/tt3397884/',
'https://www.imdb.com/title/tt2554274/',
'https://www.imdb.com/title/tt8079248/',
'https://www.imdb.com/title/tt5727208/',
'https://www.imdb.com/title/tt6105098/',
'https://www.imdb.com/title/tt0478970/',
'https://www.imdb.com/title/tt2802144/',
'https://www.imdb.com/title/tt6911608/',
'https://www.imdb.com/title/tt1051906/',
'https://www.imdb.com/title/tt6857112/',
'https://www.imdb.com/title/tt3731562/',
'https://www.imdb.com/title/tt4034228/',
'https://www.imdb.com/title/tt1631867/',
'https://www.imdb.com/title/tt1469304/',
'https://www.imdb.com/title/tt3659388/',
'https://www.imdb.com/title/tt3741700/',
'https://www.imdb.com/title/tt1611224/',
'https://www.imdb.com/title/tt2975590/',
'https://www.imdb.com/title/tt6079516/',
'https://www.imdb.com/title/tt4263482/',
'https://www.imdb.com/title/tt7984766/',
'https://www.imdb.com/title/tt3778644/',
'https://www.imdb.com/title/tt3794354/',
'https://www.imdb.com/title/tt7070818/',
'https://www.imdb.com/title/tt5095030/',
'https://www.imdb.com/title/tt1343092/',
'https://www.imdb.com/title/tt11161474/',
'https://www.imdb.com/title/tt3460252/',
'https://www.imdb.com/title/tt8695030/',
'https://www.imdb.com/title/tt10514222/',
'https://www.imdb.com/title/tt1925435/',
'https://www.imdb.com/title/tt5580390/',
'https://www.imdb.com/title/tt5606664/',
'https://www.imdb.com/title/tt1300854/',
'https://www.imdb.com/title/tt1981115/',
'https://www.imdb.com/title/tt6139732/',
'https://www.imdb.com/title/tt5580036/',
'https://www.imdb.com/title/tt2397535/',
'https://www.imdb.com/title/tt1800241/',
'https://www.imdb.com/title/tt1951264/',
'https://www.imdb.com/title/tt5164214/',
'https://www.imdb.com/title/tt1907668/',
'https://www.imdb.com/title/tt0816711/',
'https://www.imdb.com/title/tt1454029/',
'https://www.imdb.com/title/tt6772802/',
'https://www.imdb.com/title/tt1840309/',
'https://www.imdb.com/title/tt7975244/',
'https://www.imdb.com/title/tt5113040/',
'https://www.imdb.com/title/tt3315342/',
'https://www.imdb.com/title/tt2084970/',
'https://www.imdb.com/title/tt7556122/',
'https://www.imdb.com/title/tt2235695/',
'https://www.imdb.com/title/tt2191701/',
'https://www.imdb.com/title/tt6394270/',
'https://www.imdb.com/title/tt2771200/',
'https://www.imdb.com/title/tt1446714/',
'https://www.imdb.com/title/tt3464902/',
'https://www.imdb.com/title/tt5362988/',
'https://www.imdb.com/title/tt8244784/',
'https://www.imdb.com/title/tt2948356/',
'https://www.imdb.com/title/tt4123430/',
'https://www.imdb.com/title/tt0780504/',
'https://www.imdb.com/title/tt1895587/',
'https://www.imdb.com/title/tt3605418/',
'https://www.imdb.com/title/tt8784956/',
'https://www.imdb.com/title/tt1564367/',
'https://www.imdb.com/title/tt3783958/',
'https://www.imdb.com/title/tt1596363/',
'https://www.imdb.com/title/tt1663202/',
'https://www.imdb.com/title/tt3170832/',
'https://www.imdb.com/title/tt2380307/',
'https://www.imdb.com/title/tt3799694/',
'https://www.imdb.com/title/tt4975722/',
'https://www.imdb.com/title/tt8106534/',
'https://www.imdb.com/title/tt7798634/',
'https://www.imdb.com/title/tt2872718/',
'https://www.imdb.com/title/tt2096673/',
'https://www.imdb.com/title/tt10003008/',
'https://www.imdb.com/title/tt4555426/',
'https://www.imdb.com/title/tt1568346/',
'https://www.imdb.com/title/tt0369610/',
'https://www.imdb.com/title/tt1798709/',
'https://www.imdb.com/title/tt0437086/',
'https://www.imdb.com/title/tt2488496/',
'https://www.imdb.com/title/tt1748122/',
'https://www.imdb.com/title/tt2316204/',
'https://www.imdb.com/title/tt2277860/',
'https://www.imdb.com/title/tt2261331/',
'https://www.imdb.com/title/tt1086064/',
'https://www.imdb.com/title/tt0770828/',
'https://www.imdb.com/title/tt7653254/',
'https://www.imdb.com/title/tt3385516/',
'https://www.imdb.com/title/tt4160708/',
'https://www.imdb.com/title/tt2527336/',
'https://www.imdb.com/title/tt8267604/',
'https://www.imdb.com/title/tt4630562/',
'https://www.imdb.com/title/tt3833480/',
'https://www.imdb.com/title/tt1707386/',
'https://www.imdb.com/title/tt3402236/',
'https://www.imdb.com/title/tt8936646/',
'https://www.imdb.com/title/tt1560220/',
'https://www.imdb.com/title/tt2660888/',
'https://www.imdb.com/title/tt2381249/',
'https://www.imdb.com/title/tt5503686/',
'https://www.imdb.com/title/tt6146586/',
'https://www.imdb.com/title/tt3470600/',
'https://www.imdb.com/title/tt8884906/',
'https://www.imdb.com/title/tt1024648/',
'https://www.imdb.com/title/tt2737304/',
'https://www.imdb.com/title/tt1655441/',
'https://www.imdb.com/title/tt2850386/',
'https://www.imdb.com/title/tt10612922/',
'https://www.imdb.com/title/tt6450804/',
'https://www.imdb.com/title/tt2820852/',
'https://www.imdb.com/title/tt3521126/',
'https://www.imdb.com/title/tt1723121/',
'https://www.imdb.com/title/tt1638355/',
'https://www.imdb.com/title/tt4846340/',
'https://www.imdb.com/title/tt5774060/',
'https://www.imdb.com/title/tt1659337/',
'https://www.imdb.com/title/tt1598778/',
'https://www.imdb.com/title/tt1670345/',
'https://www.imdb.com/title/tt10919380/',
'https://www.imdb.com/title/tt1025100/',
'https://www.imdb.com/title/tt4649466/',
'https://www.imdb.com/title/tt5774062/',
'https://www.imdb.com/title/tt3797868/',
'https://www.imdb.com/title/tt6048922/',
'https://www.imdb.com/title/tt7040874/',
'https://www.imdb.com/title/tt1790809/',
'https://www.imdb.com/title/tt7959026/',
'https://www.imdb.com/title/tt1790864/',
'https://www.imdb.com/title/tt3569230/',
'https://www.imdb.com/title/tt7939766/',
'https://www.imdb.com/title/tt1322269/',
'https://www.imdb.com/title/tt1355644/',
'https://www.imdb.com/title/tt4779326/',
'https://www.imdb.com/title/tt7711170/',
'https://www.imdb.com/title/tt0800325/',
'https://www.imdb.com/title/tt8846176/',
'https://www.imdb.com/title/tt4139588/',
'https://www.imdb.com/title/tt6924650/',
'https://www.imdb.com/title/tt7983894/',
'https://www.imdb.com/title/tt1034415/',
'https://www.imdb.com/title/tt5109784/',
'https://www.imdb.com/title/tt1210166/',
'https://www.imdb.com/title/tt5697572/',
'https://www.imdb.com/title/tt4425200/',
'https://www.imdb.com/title/tt4364194/',
'https://www.imdb.com/title/tt5715874/',
'https://www.imdb.com/title/tt3824648/',
'https://www.imdb.com/title/tt3631112/',
'https://www.imdb.com/title/tt1253863/',
'https://www.imdb.com/title/tt5093026/',
'https://www.imdb.com/title/tt1502712/',
'https://www.imdb.com/title/tt2294629/',
'https://www.imdb.com/title/tt5442430/',
'https://www.imdb.com/title/tt1637688/',
'https://www.imdb.com/title/tt3065204/',
'https://www.imdb.com/title/tt5083738/',
'https://www.imdb.com/title/tt6412452/',
'https://www.imdb.com/title/tt1291584/',
'https://www.imdb.com/title/tt0831387/',
'https://www.imdb.com/title/tt1502397/',
'https://www.imdb.com/title/tt10539608/',
'https://www.imdb.com/title/tt6398184/',
'https://www.imdb.com/title/tt1489887/',
'https://www.imdb.com/title/tt4925292/',
'https://www.imdb.com/title/tt2024544/',
'https://www.imdb.com/title/tt1617661/',
'https://www.imdb.com/title/tt0805647/',
'https://www.imdb.com/title/tt1170358/',
'https://www.imdb.com/title/tt1232200/',
'https://www.imdb.com/title/tt2873282/',
'https://www.imdb.com/title/tt5420210/',
'https://www.imdb.com/title/tt4560436/',
'https://www.imdb.com/title/tt7456310/',
'https://www.imdb.com/title/tt1877832/',
'https://www.imdb.com/title/tt1951266/',
'https://www.imdb.com/title/tt9243946/',
'https://www.imdb.com/title/tt3183660/',
'https://www.imdb.com/title/tt9731534/',
'https://www.imdb.com/title/tt0918940/',
'https://www.imdb.com/title/tt1259521/',
'https://www.imdb.com/title/tt1961175/',
'https://www.imdb.com/title/tt4463894/',
'https://www.imdb.com/title/tt1790885/',
'https://www.imdb.com/title/tt7401588/',
'https://www.imdb.com/title/tt1270798/',
'https://www.imdb.com/title/tt1905041/',
'https://www.imdb.com/title/tt1189340/',
'https://www.imdb.com/title/tt0455944/',
'https://www.imdb.com/title/tt7139936/',
'https://www.imdb.com/title/tt3829266/',
'https://www.imdb.com/title/tt1509767/',
'https://www.imdb.com/title/tt9252488/',
'https://www.imdb.com/title/tt1637725/',
'https://www.imdb.com/title/tt2704998/',
'https://www.imdb.com/title/tt3741834/',
'https://www.imdb.com/title/tt7146812/',
'https://www.imdb.com/title/tt2719848/',
'https://www.imdb.com/title/tt1937390/',
'https://www.imdb.com/title/tt6265828/',
'https://www.imdb.com/title/tt9147456/',
'https://www.imdb.com/title/tt1045658/',
'https://www.imdb.com/title/tt7958736/',
'https://www.imdb.com/title/tt1649419/',
'https://www.imdb.com/title/tt1436562/',
'https://www.imdb.com/title/tt3099498/',
'https://www.imdb.com/title/tt1632708/',
'https://www.imdb.com/title/tt6513120/',
'https://www.imdb.com/title/tt5033998/',
'https://www.imdb.com/title/tt4225622/',
'https://www.imdb.com/title/tt1583421/',
'https://www.imdb.com/title/tt0948470/',
'https://www.imdb.com/title/tt7349662/',
'https://www.imdb.com/title/tt2239822/',
'https://www.imdb.com/title/tt4846232/',
'https://www.imdb.com/title/tt9340860/',
'https://www.imdb.com/title/tt6266538/',
'https://www.imdb.com/title/tt2245084/',
'https://www.imdb.com/title/tt4172430/',
'https://www.imdb.com/title/tt2184339/',
'https://www.imdb.com/title/tt1213663/',
'https://www.imdb.com/title/tt0978764/',
'https://www.imdb.com/title/tt10065694/',
'https://www.imdb.com/title/tt1735898/',
'https://www.imdb.com/title/tt1277953/',
'https://www.imdb.com/title/tt8110640/',
'https://www.imdb.com/title/tt10344522/',
'https://www.imdb.com/title/tt13143964/',
'https://www.imdb.com/title/tt5867314/',
'https://www.imdb.com/title/tt4881806/',
'https://www.imdb.com/title/tt3181822/',
'https://www.imdb.com/title/tt1935859/',
'https://www.imdb.com/title/tt7525778/',
'https://www.imdb.com/title/tt4477536/',
'https://www.imdb.com/title/tt1276104/',
'https://www.imdb.com/title/tt6998518/',
'https://www.imdb.com/title/tt2302755/',
'https://www.imdb.com/title/tt2381991/',
'https://www.imdb.com/title/tt1086772/',
'https://www.imdb.com/title/tt6977338/',
'https://www.imdb.com/title/tt3513548/',
'https://www.imdb.com/title/tt9264728/',
'https://www.imdb.com/title/tt1343727/',
'https://www.imdb.com/title/tt2481498/',
'https://www.imdb.com/title/tt3606756/',
'https://www.imdb.com/title/tt1232829/',
'https://www.imdb.com/title/tt1951265/',
'https://www.imdb.com/title/tt4530422/',
'https://www.imdb.com/title/tt3682448/',
'https://www.imdb.com/title/tt1298650/',
'https://www.imdb.com/title/tt0790636/',
'https://www.imdb.com/title/tt1673434/',
'https://www.imdb.com/title/tt4540710/',
'https://www.imdb.com/title/tt1560747/',
'https://www.imdb.com/title/tt1206885/',
'https://www.imdb.com/title/tt4332232/',
'https://www.imdb.com/title/tt1229238/',
'https://www.imdb.com/title/tt2582782/',
'https://www.imdb.com/title/tt8430598/',
'https://www.imdb.com/title/tt2179136/',
'https://www.imdb.com/title/tt6673612/',
'https://www.imdb.com/title/tt0359950/',
'https://www.imdb.com/title/tt1245492/',
'https://www.imdb.com/title/tt2400463/',
'https://www.imdb.com/title/tt1454468/',
'https://www.imdb.com/title/tt5776858/',
'https://www.imdb.com/title/tt5884052/',
'https://www.imdb.com/title/tt1365519/',
'https://www.imdb.com/title/tt9690328/',
'https://www.imdb.com/title/tt1809398/',
'https://www.imdb.com/title/tt5439796/',
'https://www.imdb.com/title/tt6628394/',
'https://www.imdb.com/title/tt4334266/',
'https://www.imdb.com/title/tt2140479/',
'https://www.imdb.com/title/tt9071322/',
'https://www.imdb.com/title/tt9580138/',
'https://www.imdb.com/title/tt2310332/',
'https://www.imdb.com/title/tt4520988/',
'https://www.imdb.com/title/tt2562232/',
'https://www.imdb.com/title/tt0491203/',
'https://www.imdb.com/title/tt8629748/',
'https://www.imdb.com/title/tt1872181/',
'https://www.imdb.com/title/tt2126355/',
'https://www.imdb.com/title/tt1483013/',
'https://www.imdb.com/title/tt2334879/',
'https://www.imdb.com/title/tt4209788/',
'https://www.imdb.com/title/tt1979376/',
'https://www.imdb.com/title/tt1634106/',
'https://www.imdb.com/title/tt4686844/',
'https://www.imdb.com/title/tt1217209/',
'https://www.imdb.com/title/tt0790724/',
'https://www.imdb.com/title/tt8364368/',
'https://www.imdb.com/title/tt4669788/',
'https://www.imdb.com/title/tt1413492/',
'https://www.imdb.com/title/tt2345759/',
'https://www.imdb.com/title/tt1133985/',
'https://www.imdb.com/title/tt1723811/',
'https://www.imdb.com/title/tt10600398/',
'https://www.imdb.com/title/tt1289401/',
'https://www.imdb.com/title/tt2229499/',
'https://www.imdb.com/title/tt1272878/',
'https://www.imdb.com/title/tt3062096/',
'https://www.imdb.com/title/tt1489889/',
'https://www.imdb.com/title/tt1981128/',
'https://www.imdb.com/title/tt11024272/',
'https://www.imdb.com/title/tt4178092/',
'https://www.imdb.com/title/tt1212450/',
'https://www.imdb.com/title/tt3076658/',
'https://www.imdb.com/title/tt1922777/',
'https://www.imdb.com/title/tt1298649/',
'https://www.imdb.com/title/tt1730768/',
'https://www.imdb.com/title/tt2677722/',
'https://www.imdb.com/title/tt5814060/',
'https://www.imdb.com/title/tt0983946/',
'https://www.imdb.com/title/tt1333125/',
'https://www.imdb.com/title/tt2950418/',
'https://www.imdb.com/title/tt4537896/',
'https://www.imdb.com/title/tt1974419/',
'https://www.imdb.com/title/tt2005151/',
'https://www.imdb.com/title/tt1374989/',
'https://www.imdb.com/title/tt8350360/',
'https://www.imdb.com/title/tt1817273/',
'https://www.imdb.com/title/tt1335975/',
'https://www.imdb.com/title/tt1289403/',
'https://www.imdb.com/title/tt2404233/',
'https://www.imdb.com/title/tt1093357/',
'https://www.imdb.com/title/tt0401729/',
'https://www.imdb.com/title/tt5052474/',
'https://www.imdb.com/title/tt3532216/',
'https://www.imdb.com/title/tt0945513/',
'https://www.imdb.com/title/tt6587640/',
'https://www.imdb.com/title/tt2403021/',
'https://www.imdb.com/title/tt2180411/',
'https://www.imdb.com/title/tt5073642/',
'https://www.imdb.com/title/tt4481414/',
'https://www.imdb.com/title/tt2404435/',
'https://www.imdb.com/title/tt1077368/',
'https://www.imdb.com/title/tt3235888/',
'https://www.imdb.com/title/tt2935510/',
'https://www.imdb.com/title/tt12592252/',
'https://www.imdb.com/title/tt1987680/',
'https://www.imdb.com/title/tt4532038/',
'https://www.imdb.com/title/tt8688634/',
'https://www.imdb.com/title/tt1700841/',
'https://www.imdb.com/title/tt7550000/',
'https://www.imdb.com/title/tt2388771/',
'https://www.imdb.com/title/tt3799232/',
'https://www.imdb.com/title/tt2034800/',
'https://www.imdb.com/title/tt3748172/',
'https://www.imdb.com/title/tt10272386/',
'https://www.imdb.com/title/tt8043434/',
'https://www.imdb.com/title/tt10059518/',
'https://www.imdb.com/title/tt6842770/',
'https://www.imdb.com/title/tt7846844/',
'https://www.imdb.com/title/tt10279362/',
'https://www.imdb.com/title/tt9214832/',
'https://www.imdb.com/title/tt7557108/',
'https://www.imdb.com/title/tt8338762/',
'https://www.imdb.com/title/tt0470752/',
'https://www.imdb.com/title/tt2235695/',
'https://www.imdb.com/title/tt2194499/',
'https://www.imdb.com/title/tt2798920/',
'https://www.imdb.com/title/tt1905041/',
'https://www.imdb.com/title/tt1937390/',
'https://www.imdb.com/title/tt5918982/',
'https://www.imdb.com/title/tt6902676/',
'https://www.imdb.com/title/tt1441395/',
'https://www.imdb.com/title/tt8508734/',
'https://www.imdb.com/title/tt1781769/',
'https://www.imdb.com/title/tt2872732/',
'https://www.imdb.com/title/tt5198068/',
'https://www.imdb.com/title/tt1340800/',
'https://www.imdb.com/title/tt0475290/',
'https://www.imdb.com/title/tt5719748/',
'https://www.imdb.com/title/tt1464763/',
'https://www.imdb.com/title/tt5114840/',
'https://www.imdb.com/title/tt3300542/',
'https://www.imdb.com/title/tt3079380/',
'https://www.imdb.com/title/tt1846589/',
'https://www.imdb.com/title/tt2592614/',
'https://www.imdb.com/title/tt1121096/',
'https://www.imdb.com/title/tt2274648/',
'https://www.imdb.com/title/tt1411238/',
'https://www.imdb.com/title/tt1587310/',
'https://www.imdb.com/title/tt8333746/',
'https://www.imdb.com/title/tt5797184/',
'https://www.imdb.com/title/tt5638642/',
'https://www.imdb.com/title/tt2980516/',
'https://www.imdb.com/title/tt2140507/',
'https://www.imdb.com/title/tt2837574/',
'https://www.imdb.com/title/tt1091191/',
'https://www.imdb.com/title/tt1966385/',
'https://www.imdb.com/title/tt1318514/',
'https://www.imdb.com/title/tt3152592/',
'https://www.imdb.com/title/tt4468740/',
'https://www.imdb.com/title/tt0993842/',
'https://www.imdb.com/title/tt1536537/',
'https://www.imdb.com/title/tt8201852/',
'https://www.imdb.com/title/tt5028340/',
'https://www.imdb.com/title/tt3640424/',
'https://www.imdb.com/title/tt1430132/',
'https://www.imdb.com/title/tt9179096/',
'https://www.imdb.com/title/tt0454876/',
'https://www.imdb.com/title/tt0810819/',
'https://www.imdb.com/title/tt7347846/',
'https://www.imdb.com/title/tt6679794/',
'https://www.imdb.com/title/tt0490215/',
'https://www.imdb.com/title/tt1931533/',
'https://www.imdb.com/title/tt2980592/',
'https://www.imdb.com/title/tt1758810/',
'https://www.imdb.com/title/tt1253864/',
'https://www.imdb.com/title/tt1515091/',
'https://www.imdb.com/title/tt0829150/',
'https://www.imdb.com/title/tt5104604/',
'https://www.imdb.com/title/tt2328900/',
'https://www.imdb.com/title/tt0462335/',
'https://www.imdb.com/title/tt1734493/',
'https://www.imdb.com/title/tt2103281/',
'https://www.imdb.com/title/tt3040964/',
'https://www.imdb.com/title/tt9182964/',
'https://www.imdb.com/title/tt2494362/',
'https://www.imdb.com/title/tt1638002/',
'https://www.imdb.com/title/tt1502407/',
'https://www.imdb.com/title/tt4777008/',
'https://www.imdb.com/title/tt6017756/',
'https://www.imdb.com/title/tt2402927/',
'https://www.imdb.com/title/tt1893256/',
'https://www.imdb.com/title/tt4218572/',
'https://www.imdb.com/title/tt3014866/',
'https://www.imdb.com/title/tt10262380/',
'https://www.imdb.com/title/tt2866360/',
'https://www.imdb.com/title/tt10334148/',
'https://www.imdb.com/title/tt5814534/',
'https://www.imdb.com/title/tt1242460/',
'https://www.imdb.com/title/tt3917506/',
'https://www.imdb.com/title/tt1964418/',
'https://www.imdb.com/title/tt3774114/',
'https://www.imdb.com/title/tt1853739/',
'https://www.imdb.com/title/tt8266310/',
'https://www.imdb.com/title/tt5932728/',
'https://www.imdb.com/title/tt0970179/',
'https://www.imdb.com/title/tt1855325/',
'https://www.imdb.com/title/tt6108178/',
'https://www.imdb.com/title/tt5431890/',
'https://www.imdb.com/title/tt2209764/',
'https://www.imdb.com/title/tt1615160/',
'https://www.imdb.com/title/tt6294822/',
'https://www.imdb.com/title/tt2404425/',
'https://www.imdb.com/title/tt2094766/',
'https://www.imdb.com/title/tt7134096/',
'https://www.imdb.com/title/tt2080374/',
'https://www.imdb.com/title/tt5742374/',
'https://www.imdb.com/title/tt3721936/',
'https://www.imdb.com/title/tt6476140/',
'https://www.imdb.com/title/tt9285882/',
'https://www.imdb.com/title/tt1972571/',
'https://www.imdb.com/title/tt1092026/',
'https://www.imdb.com/title/tt11169050/',
'https://www.imdb.com/title/tt6511932/',
'https://www.imdb.com/title/tt1109624/',
'https://www.imdb.com/title/tt6439020/',
'https://www.imdb.com/title/tt1895315/',
'https://www.imdb.com/title/tt12749596/',
'https://www.imdb.com/title/tt8717446/',
'https://www.imdb.com/title/tt4721124/',
'https://www.imdb.com/title/tt4844140/',
'https://www.imdb.com/title/tt8419594/',
'https://www.imdb.com/title/tt3011894/',
'https://www.imdb.com/title/tt1563738/',
'https://www.imdb.com/title/tt1869347/',
'https://www.imdb.com/title/tt5716464/',
'https://www.imdb.com/title/tt5294550/',
'https://www.imdb.com/title/tt7772582/',
'https://www.imdb.com/title/tt9308382/',
'https://www.imdb.com/title/tt4827558/',
'https://www.imdb.com/title/tt3296908/',
'https://www.imdb.com/title/tt6217306/',
'https://www.imdb.com/title/tt1714915/',
'https://www.imdb.com/title/tt2692904/',
'https://www.imdb.com/title/tt9387250/',
'https://www.imdb.com/title/tt1650554/',
'https://www.imdb.com/title/tt2503944/',
'https://www.imdb.com/title/tt5397194/',
'https://www.imdb.com/title/tt6882604/',
'https://www.imdb.com/title/tt7549996/',
'https://www.imdb.com/title/tt3758172/',
'https://www.imdb.com/title/tt1538403/',
'https://www.imdb.com/title/tt3312830/',
'https://www.imdb.com/title/tt5117670/',
'https://www.imdb.com/title/tt13299678/',
'https://www.imdb.com/title/tt10310140/',
'https://www.imdb.com/title/tt5177088/',
'https://www.imdb.com/title/tt11576124/',
'https://www.imdb.com/title/tt1401152/',
'https://www.imdb.com/title/tt0983193/',
'https://www.imdb.com/title/tt5834262/',
'https://www.imdb.com/title/tt2304933/',
'https://www.imdb.com/title/tt1860213/',
'https://www.imdb.com/title/tt2763304/',
'https://www.imdb.com/title/tt9883996/',
'https://www.imdb.com/title/tt2381111/',
'https://www.imdb.com/title/tt2692250/',
'https://www.imdb.com/title/tt2557478/',
'https://www.imdb.com/title/tt1606378/',
'https://www.imdb.com/title/tt5592796/',
'https://www.imdb.com/title/tt1590193/',
'https://www.imdb.com/title/tt2132285/',
'https://www.imdb.com/title/tt1355631/',
'https://www.imdb.com/title/tt1273221/',
'https://www.imdb.com/title/tt2932536/',
'https://www.imdb.com/title/tt1528100/',
'https://www.imdb.com/title/tt2042568/',
'https://www.imdb.com/title/tt5714470/',
'https://www.imdb.com/title/tt0377981/',
'https://www.imdb.com/title/tt5827916/',
'https://www.imdb.com/title/tt2382009/',
'https://www.imdb.com/title/tt2515034/',
'https://www.imdb.com/title/tt3332064/',
'https://www.imdb.com/title/tt1355683/',
'https://www.imdb.com/title/tt5977276/',
'https://www.imdb.com/title/tt3289956/',
'https://www.imdb.com/title/tt1206543/',
'https://www.imdb.com/title/tt3381008/',
'https://www.imdb.com/title/tt2935476/',
'https://www.imdb.com/title/tt8404614/',
'https://www.imdb.com/title/tt1517260/',
'https://www.imdb.com/title/tt4465572/',
'https://www.imdb.com/title/tt1351685/',
'https://www.imdb.com/title/tt4463816/',
'https://www.imdb.com/title/tt4005402/',
'https://www.imdb.com/title/tt5461944/',
'https://www.imdb.com/title/tt1204340/',
'https://www.imdb.com/title/tt9138170/',
'https://www.imdb.com/title/tt2702920/',
'https://www.imdb.com/title/tt6914122/',
'https://www.imdb.com/title/tt0458413/',
'https://www.imdb.com/title/tt9207700/',
'https://www.imdb.com/title/tt1767354/',
'https://www.imdb.com/title/tt4729430/',
'https://www.imdb.com/title/tt6508228/',
'https://www.imdb.com/title/tt7329642/',
'https://www.imdb.com/title/tt1229822/',
'https://www.imdb.com/title/tt5715066/',
'https://www.imdb.com/title/tt1034389/',
'https://www.imdb.com/title/tt9652730/',
'https://www.imdb.com/title/tt3691740/',
'https://www.imdb.com/title/tt2404311/',
'https://www.imdb.com/title/tt8342680/',
'https://www.imdb.com/title/tt9340872/',
'https://www.imdb.com/title/tt1682180/',
'https://www.imdb.com/title/tt4547056/',
'https://www.imdb.com/title/tt6141246/',
'https://www.imdb.com/title/tt4154916/',
'https://www.imdb.com/title/tt6212478/',
'https://www.imdb.com/title/tt2193215/',
'https://www.imdb.com/title/tt9784456/',
'https://www.imdb.com/title/tt3544112/',
'https://www.imdb.com/title/tt3861390/',
'https://www.imdb.com/title/tt2679042/',
'https://www.imdb.com/title/tt9207616/',
'https://www.imdb.com/title/tt4158096/',
'https://www.imdb.com/title/tt9148706/',
'https://www.imdb.com/title/tt1686821/',
'https://www.imdb.com/title/tt3064298/',
'https://www.imdb.com/title/tt8710596/',
'https://www.imdb.com/title/tt7510346/',
'https://www.imdb.com/title/tt2140373/',
'https://www.imdb.com/title/tt6938828/',
'https://www.imdb.com/title/tt1596365/',
'https://www.imdb.com/title/tt1571222/',
'https://www.imdb.com/title/tt5206260/',
'https://www.imdb.com/title/tt6053438/',
'https://www.imdb.com/title/tt0905372/',
'https://www.imdb.com/title/tt1564777/',
'https://www.imdb.com/title/tt7329656/',
'https://www.imdb.com/title/tt5563334/',
'https://www.imdb.com/title/tt6095472/',
'https://www.imdb.com/title/tt1204342/',
'https://www.imdb.com/title/tt8623904/',
'https://www.imdb.com/title/tt5074352/',
'https://www.imdb.com/title/tt3416532/',
'https://www.imdb.com/title/tt1655420/',
'https://www.imdb.com/title/tt9143112/',
'https://www.imdb.com/title/tt2368619/',
'https://www.imdb.com/title/tt0337692/',
'https://www.imdb.com/title/tt2567026/',
'https://www.imdb.com/title/tt2481198/',
'https://www.imdb.com/title/tt5437928/',
'https://www.imdb.com/title/tt1014763/',
'https://www.imdb.com/title/tt3949660/',
'https://www.imdb.com/title/tt0900387/',
'https://www.imdb.com/title/tt1450321/',
'https://www.imdb.com/title/tt1297919/',
'https://www.imdb.com/title/tt1724970/',
'https://www.imdb.com/title/tt4106514/',
'https://www.imdb.com/title/tt1478964/',
'https://www.imdb.com/title/tt0882977/',
'https://www.imdb.com/title/tt2547584/',
'https://www.imdb.com/title/tt5096470/',
'https://www.imdb.com/title/tt3416828/',
'https://www.imdb.com/title/tt4180560/',
'https://www.imdb.com/title/tt7533152/',
'https://www.imdb.com/title/tt4575576/',
'https://www.imdb.com/title/tt2024469/',
'https://www.imdb.com/title/tt3195644/',
'https://www.imdb.com/title/tt1397280/',
'https://www.imdb.com/title/tt1921064/',
'https://www.imdb.com/title/tt9806370/',
'https://www.imdb.com/title/tt5360996/',
'https://www.imdb.com/title/tt1318517/',
'https://www.imdb.com/title/tt1716772/',
'https://www.imdb.com/title/tt4622512/',
'https://www.imdb.com/title/tt2884018/',
'https://www.imdb.com/title/tt4703048/',
'https://www.imdb.com/title/tt4190530/',
'https://www.imdb.com/title/tt1448755/',
'https://www.imdb.com/title/tt1667889/',
'https://www.imdb.com/title/tt2639254/',
'https://www.imdb.com/title/tt1020072/',
'https://www.imdb.com/title/tt4136084/',
'https://www.imdb.com/title/tt6479178/',
'https://www.imdb.com/title/tt2718492/',
'https://www.imdb.com/title/tt5635086/',
'https://www.imdb.com/title/tt1412386/',
'https://www.imdb.com/title/tt2401878/',
'https://www.imdb.com/title/tt6811018/',
'https://www.imdb.com/title/tt6841122/',
'https://www.imdb.com/title/tt2402101/',
'https://www.imdb.com/title/tt6543652/',
'https://www.imdb.com/title/tt2980210/',
'https://www.imdb.com/title/tt8400758/',
'https://www.imdb.com/title/tt8000908/',
'https://www.imdb.com/title/tt1985949/',
'https://www.imdb.com/title/tt1726592/',
'https://www.imdb.com/title/tt1619029/',
'https://www.imdb.com/title/tt2402157/',
'https://www.imdb.com/title/tt10831086/',
'https://www.imdb.com/title/tt1741273/',
'https://www.imdb.com/title/tt2473602/',
'https://www.imdb.com/title/tt3316960/',
'https://www.imdb.com/title/tt3750872/',
'https://www.imdb.com/title/tt7156898/',
'https://www.imdb.com/title/tt3835080/',
'https://www.imdb.com/title/tt3322364/',
'https://www.imdb.com/title/tt6828390/',
'https://www.imdb.com/title/tt1034314/',
'https://www.imdb.com/title/tt4687856/',
'https://www.imdb.com/title/tt7241926/',
'https://www.imdb.com/title/tt1780967/',
'https://www.imdb.com/title/tt1524137/',
'https://www.imdb.com/title/tt2431286/',
'https://www.imdb.com/title/tt6210996/',
'https://www.imdb.com/title/tt4669296/',
'https://www.imdb.com/title/tt2281587/',
'https://www.imdb.com/title/tt4992060/',
'https://www.imdb.com/title/tt6921996/',
'https://www.imdb.com/title/tt9824114/',
'https://www.imdb.com/title/tt8484160/',
'https://www.imdb.com/title/tt1657507/',
'https://www.imdb.com/title/tt0975645/',
'https://www.imdb.com/title/tt4291600/',
'https://www.imdb.com/title/tt7587876/',
'https://www.imdb.com/title/tt6218358/',
'https://www.imdb.com/title/tt9752248/',
'https://www.imdb.com/title/tt5929654/',
'https://www.imdb.com/title/tt6515910/',
'https://www.imdb.com/title/tt3169706/',
'https://www.imdb.com/title/tt1645131/',
'https://www.imdb.com/title/tt1439572/',
'https://www.imdb.com/title/tt4131496/',
'https://www.imdb.com/title/tt3541524/',
'https://www.imdb.com/title/tt5068162/',
'https://www.imdb.com/title/tt2077886/',
'https://www.imdb.com/title/tt5690810/',
'https://www.imdb.com/title/tt1634122/',
'https://www.imdb.com/title/tt1924429/',
'https://www.imdb.com/title/tt1976009/',
'https://www.imdb.com/title/tt5316540/',
'https://www.imdb.com/title/tt1083452/',
'https://www.imdb.com/title/tt2752772/',
'https://www.imdb.com/title/tt5978724/',
'https://www.imdb.com/title/tt1648186/',
'https://www.imdb.com/title/tt1531901/',
'https://www.imdb.com/title/tt0787524/',
'https://www.imdb.com/title/tt6920356/',
'https://www.imdb.com/title/tt6905696/',
'https://www.imdb.com/title/tt2057392/',
'https://www.imdb.com/title/tt2614684/',
'https://www.imdb.com/title/tt1473832/',
'https://www.imdb.com/title/tt4255304/',
'https://www.imdb.com/title/tt3859310/',
'https://www.imdb.com/title/tt1788391/',
'https://www.imdb.com/title/tt1795702/',
'https://www.imdb.com/title/tt1007029/',
'https://www.imdb.com/title/tt2720680/',
'https://www.imdb.com/title/tt4986098/',
'https://www.imdb.com/title/tt8000718/',
'https://www.imdb.com/title/tt4645330/',
'https://www.imdb.com/title/tt0376136/',
'https://www.imdb.com/title/tt1441951/',
'https://www.imdb.com/title/tt4229826/',
'https://www.imdb.com/title/tt5607096/',
'https://www.imdb.com/title/tt0491175/',
'https://www.imdb.com/title/tt7026672/',
'https://www.imdb.com/title/tt5664636/',
'https://www.imdb.com/title/tt3282076/',
'https://www.imdb.com/title/tt8058874/',
'https://www.imdb.com/title/tt8836988/',
'https://www.imdb.com/title/tt8359816/',
'https://www.imdb.com/title/tt3045616/',
'https://www.imdb.com/title/tt2725962/',
'https://www.imdb.com/title/tt1334102/',
'https://www.imdb.com/title/tt3262342/',
'https://www.imdb.com/title/tt4080956/',
'https://www.imdb.com/title/tt1763264/',
'https://www.imdb.com/title/tt1441953/',
'https://www.imdb.com/title/tt4460792/',
'https://www.imdb.com/title/tt7985692/',
'https://www.imdb.com/title/tt3787590/',
'https://www.imdb.com/title/tt1613750/',
'https://www.imdb.com/title/tt4581576/',
'https://www.imdb.com/title/tt1657517/',
'https://www.imdb.com/title/tt5913798/',
'https://www.imdb.com/title/tt3171832/',
'https://www.imdb.com/title/tt3077214/',
'https://www.imdb.com/title/tt9694312/',
'https://www.imdb.com/title/tt4547194/',
'https://www.imdb.com/title/tt4042818/',
'https://www.imdb.com/title/tt2771372/'    
]

# %%
imdb_movie_list = []
# Getting the various fields and creating a list of objects with details


for i in tqdm(range(0, len(title_links)), desc="Movies processed", ncols=100):
    page_url = title_links[i]
    page_text = requests.get(page_url).text
    page_soup = BeautifulSoup(page_text, 'html.parser')

    # Getting movie name, year
    movie_name = (page_soup.find("div",{"class":"title_wrapper"}).get_text(strip=True).split('|')[0]).split('(')[0]
    year = ((page_soup.find("div",{"class":"title_wrapper"}).get_text(strip=True).split('|')[0]).split('(')[1]).split(')')[0]
    subtext= page_soup.find("div",{"class":"subtext"}).get_text(strip=True).split('|')
    
    if len(subtext) < 4:
        # Setting values when the movie is unrated
        censor_rating = "No rating"
        movie_length = subtext[0]
        genre_list = subtext[1].split(',')

        while len(genre_list) < 4: genre_list.append(' ')
        genre_1, genre_2, genre_3, genre_4 = genre_list
        
        #release_date_and_country = subtext[2].split('(')
        #release_date = movie_length_and_country[0]
    else: 
        censor_rating = subtext[0]
        movie_length = subtext[1]
        genre_list = subtext[2].split(',')

        while len(genre_list) < 4: genre_list.append(' ')

        movie_length_and_country = subtext[3].split('(')
        release_date = movie_length_and_country[0]

    # Getting the movie summary
    summary = page_soup.find("div",{"class":"summary_text"}).get_text(strip=True).strip()
    
    # ------------------------------------------------------------------------------------------
    # Getting the credits for the director and writers
    credit_summary = []
    for summary_item in page_soup.find_all("div",{"class":"credit_summary_item"}):
        credit_summary.append(re.split(',|:|\|',summary_item.get_text(strip=True)))
    
    stars = credit_summary.pop()[1:4]
    writers = credit_summary.pop()[1:3]
    director = credit_summary.pop()[1:]
    
    while len(writers) < 2: writers.append(" ")
    writer_1, writer_2 = writers
    writer_1 = writer_1.split('(')[0]
    writer_2 = writer_2.split('(')[0]

    while len(stars) < 3: stars.append(" ")

    # Getting the box office details for language, budget, Opening Weekend USA, 
    # Gross income worldwide and USA, and production company
    box_office_details = []
    box_office_dictionary = {'Country':'','Language':'','Budget':'', 'Opening Weekend USA':'','Gross USA':'','Cumulative Worldwide Gross':'','Production Co':''}
    for details in page_soup.find_all("div",{"class":"txt-block"}):
        detail = details.get_text(strip=True).split(':')
        if detail[0] in box_office_dictionary:
            box_office_details.append(detail)
    
    for detail in box_office_details: 
        if detail[0] in box_office_dictionary: 
            box_office_dictionary.update({detail[0] : detail[1]}) 

    country = box_office_dictionary['Country'].split("|")
    while len(country) < 4: country.append(' ')

    language = box_office_dictionary['Language'].split("|")
    while len(language) < 5: language.append(' ')

    budget = box_office_dictionary['Budget'].split('(')[0]

    opening_week_usa = ','.join((box_office_dictionary['Opening Weekend USA'].split(' ')[0]).split(',')[:-1])

    gross_usa = box_office_dictionary['Gross USA']
    gross_worldwide = box_office_dictionary['Cumulative Worldwide Gross'].split(' ')[0]
    
    production_list = box_office_dictionary['Production Co'].split('See more')[0]
    production = production_list.split(',')
    while len(production) < 4: production.append(" ")

    movie_dict = { 'ranking': i+1, 'movie_name': movie_name, 'url': page_url, 'year': year,
        'rating': rating, 'vote_count': vote_count, 'summary': summary, 'production': production,
        'director': director, 'writers': [writer_1, writer_2], 'stars':stars, 'genres': genre_list, 'release_date': release_date,
        'censor_rating': censor_rating, 'movie_length': movie_length, 'country': country,
        'language': language, 'budget': budget, 'gross_worldwide': gross_worldwide,
        'gross_usa': gross_usa,'opening_week_usa': opening_week_usa, "poster_image": poster_image }

    imdb_movie_list.append(movie_dict)
# Out:
# Movies processed: 100%|███████████████████████████████████████████| 880/880 [19:11<00:00,  1.31s/it]

# %%
## Dataframe file creation

# %%
dataframe_columns = [ 'ranking', 'movie_name', 'url', 'year', 'rating', 'vote_count', 'summary', 'production_1', 'production_2', 'production_3',
        'director', 'writer_1', 'writer_2', 'star_1', 'star_2', 'star_3', 'genre_1', 'genre_2', 'genre_3', 'genre_4','release_date', 'censor_rating', 
        'movie_length', 'country_1', 'country_2', 'country_3', 'country_4', 'language_1', 'language_2', 'language_3', 
        'language_4', 'language_5', 'budget', 'gross_worldwide', 'gross_usa','opening_week_usa']
dataframe = pd.DataFrame(columns=dataframe_columns)
dataframe
# Out:
# Empty DataFrame
# Columns: [ranking, movie_name, url, year, rating, vote_count, summary, production_1, production_2, production_3, director, writer_1, writer_2, star_1, star_2, star_3, genre_1, genre_2, genre_3, genre_4, release_date, censor_rating, movie_length, country_1, country_2, country_3, country_4, language_1, language_2, language_3, language_4, language_5, budget, gross_worldwide, gross_usa, opening_week_usa]
# Index: []
#
# [0 rows x 36 columns]

# %%
imdb_movie_list[800]
# Out:
# {'ranking': 801,
#  'movie_name': 'Contraband',
#  'url': 'https://www.imdb.com/title/tt1524137/',
#  'year': '2012',
#  'rating': '5.4',
#  'vote_count': '6,030',
#  'summary': 'To protect his brother-in-law from a drug lord, a former smuggler heads to Panama to score millions of dollars in counterfeit bills.',
#  'production': ['Universal Pictures',
#   'Relativity Media',
#   'Working Title Films',
#   ' '],
#  'director': ['Baltasar Kormákur'],
#  'writers': ['Aaron Guzikowski', 'Arnaldur Indriðason'],
#  'stars': ['Mark Wahlberg', 'Giovanni Ribisi', 'Kate Beckinsale'],
#  'genres': ['Action', 'Crime', 'Drama', ' '],
#  'release_date': '15 March 2012 ',
#  'censor_rating': '16',
#  'movie_length': '1h 49min',
#  'country': ['USA', 'UK', 'France', ' '],
#  'language': ['English', 'Spanish', ' ', ' ', ' '],
#  'budget': '$25,000,000',
#  'gross_worldwide': '$96,262,212',
#  'gross_usa': '$66,528,000',
#  'opening_week_usa': '$24,349,815',
#  'poster_image': 'https://m.media-amazon.com/images/M/MV5BNGI5ZDlkN2EtNTY5NC00ZDdjLTkzODktNzkwOGMwODcxZTI4XkEyXkFqcGdeQXVyMTMxODk2OTU@._V1_UX182_CR0,0,182,268_AL_.jpg'}

# %%
# data into the dataframe

# %%
for i in range(0, len(imdb_movie_list)):
    dataframe.at[i, 'ranking'] = imdb_movie_list[i]['ranking']
    dataframe.at[i, 'movie_name'] = imdb_movie_list[i]['movie_name']
    dataframe.at[i, 'url'] = imdb_movie_list[i]['url']
    dataframe.at[i, 'year'] = imdb_movie_list[i]['year']
    dataframe.at[i, 'rating'] = imdb_movie_list[i]['rating']
    dataframe.at[i, 'vote_count'] = imdb_movie_list[i]['vote_count']
    dataframe.at[i, 'summary'] = imdb_movie_list[i]['summary']
    dataframe.at[i, 'production_1'] = imdb_movie_list[i]['production'][0]
    dataframe.at[i, 'production_2'] = imdb_movie_list[i]['production'][1]
    dataframe.at[i, 'production_3'] = imdb_movie_list[i]['production'][2]
    dataframe.at[i, 'director'] = imdb_movie_list[i]['director'][0]
    dataframe.at[i, 'writer_1'] = imdb_movie_list[i]['writers'][0]
    dataframe.at[i, 'writer_2'] = imdb_movie_list[i]['writers'][1]
    dataframe.at[i, 'star_1'] = imdb_movie_list[i]['stars'][0]
    dataframe.at[i, 'star_2'] = imdb_movie_list[i]['stars'][1]
    dataframe.at[i, 'star_3'] = imdb_movie_list[i]['stars'][2]
    dataframe.at[i, 'genre_1'] = imdb_movie_list[i]['genres'][0]
    dataframe.at[i, 'genre_2'] = imdb_movie_list[i]['genres'][1]
    dataframe.at[i, 'genre_3'] = imdb_movie_list[i]['genres'][2]
    dataframe.at[i, 'genre_4'] = imdb_movie_list[i]['genres'][3]
    dataframe.at[i, 'release_date'] = imdb_movie_list[i]['release_date']
    dataframe.at[i, 'censor_rating'] = imdb_movie_list[i]['censor_rating']
    dataframe.at[i, 'movie_length'] = imdb_movie_list[i]['movie_length']
    dataframe.at[i, 'country_1'] = imdb_movie_list[i]['country'][0]
    dataframe.at[i, 'country_2'] = imdb_movie_list[i]['country'][1]
    dataframe.at[i, 'country_3'] = imdb_movie_list[i]['country'][2]
    dataframe.at[i, 'country_4'] = imdb_movie_list[i]['country'][3]
    dataframe.at[i, 'language_1'] = imdb_movie_list[i]['language'][0]
    dataframe.at[i, 'language_2'] = imdb_movie_list[i]['language'][1]
    dataframe.at[i, 'language_3'] = imdb_movie_list[i]['language'][2]
    dataframe.at[i, 'language_4'] = imdb_movie_list[i]['language'][3]
    dataframe.at[i, 'language_5'] = imdb_movie_list[i]['language'][4]
    dataframe.at[i, 'budget'] = imdb_movie_list[i]['budget']
    dataframe.at[i, 'gross_worldwide'] = imdb_movie_list[i]['gross_worldwide']
    dataframe.at[i, 'gross_usa'] = imdb_movie_list[i]['gross_usa']
    dataframe.at[i, 'opening_week_usa'] = imdb_movie_list[i]['opening_week_usa']

dataframe = dataframe.set_index(['ranking'], drop=False)
dataframe.head(10)
# Out:
#         ranking             movie_name                                    url  \
# ranking
# 1             1                  Tenet  https://www.imdb.com/title/tt6723592/
# 2             2              Nomadland  https://www.imdb.com/title/tt9770150/
# 3             3        A Quiet Place 2  https://www.imdb.com/title/tt8332922/
# 4             4  Promising Young Woman  https://www.imdb.com/title/tt9620292/
# 5             5              Greenland  https://www.imdb.com/title/tt7737786/
# 6             6                  Venom  https://www.imdb.com/title/tt1270797/
# 7             7                Monster  https://www.imdb.com/title/tt2850272/
# 8             8      Love and Monsters  https://www.imdb.com/title/tt2222042/
# 9             9         Sound of Metal  https://www.imdb.com/title/tt5363618/
# 10           10      Avengers: Endgame  https://www.imdb.com/title/tt4154796/
#
#          year rating vote_count  \
# ranking
# 1        2020    5.4      6,030
# 2        2020    5.4      6,030
# 3        2020    5.4      6,030
# 4        2020    5.4      6,030
# 5        2020    5.4      6,030
# 6        2018    5.4      6,030
# 7        2018    5.4      6,030
# 8        2020    5.4      6,030
# 9        2019    5.4      6,030
# 10       2019    5.4      6,030
#
#                                                    summary  \
# ranking
# 1        Armed with only one word, Tenet, and fighting ...
# 2        A woman in her sixties, after losing everythin...
# 3        Following the events at home, the Abbott famil...
# 4        A young woman, traumatized by a tragic event i...
# 5        A family struggles for survival in the face of...
# 6        A failed reporter is bonded to an alien entity...
# 7        A smart, likeable, 17-year-old film student fr...
# 8        Seven years after he survived the monster apoc...
# 9        A heavy-metal drummer's life is thrown into fr...
# 10       After the devastating events ofAvengers: Infin...
#
#                      production_1              production_2  \
# ranking
# 1                    Warner Bros.                   Syncopy
# 2         Cor Cordium Productions      Hear/Say Productions
# 3               Buffalo FilmWorks        Paramount Pictures
# 4        FilmNation Entertainment            Focus Features
# 5                       STX Films                     Anton
# 6            Avi Arad Productions         Columbia Pictures
# 7               Tonik Productions  Charlevoix Entertainment
# 8              Paramount Pictures         Entertainment One
# 9                          Caviar        Flat 7 Productions
# 10                 Marvel Studios      Walt Disney Pictures
#
#                     production_3  ... country_4 language_1  \
# ranking                           ...
# 1                                 ...              English
# 2               Highwayman Films  ...              English
# 3                 Platinum Dunes  ...              English
# 4        LuckyChap Entertainment  ...              English
# 5          Thunder Road Pictures  ...              English
# 6           Marvel Entertainment  ...              English
# 7                   BRON Studios  ...              English
# 8          21 Laps Entertainment  ...              English
# 9                      Ward Four  ...              English
# 10                                ...              English
#
#                      language_2 language_3 language_4 language_5  \
# ranking
# 1                       Russian  Ukrainian   Estonian  Norwegian
# 2
# 3
# 4
# 5
# 6                      Mandarin      Malay
# 7
# 8
# 9        American Sign Language     French
# 10                     Japanese      Xhosa     German
#
#                budget gross_worldwide     gross_usa opening_week_usa
# ranking
# 1        $205,000,000    $363,656,624   $58,456,624       $9,353,090
# 2                          $7,379,524    $2,143,000         $503,000
# 3
# 4                         $13,868,965    $6,460,965         $719,305
# 5                         $52,300,000
# 6        $100,000,000    $856,085,151  $213,515,506      $80,255,756
# 7
# 8                          $1,122,066    $1,070,714         $270,302
# 9                            $181,421
# 10       $356,000,000  $2,797,501,328  $858,373,000     $357,115,007
#
# [10 rows x 36 columns]

# %%
#save dataframe into csv and excel

# %%
dataframe.to_csv('imdb_movies_data.csv')

# %%
dataframe.to_excel('imbd_movies_data.xlsx')
